# %% [markdown]
# ## Task 4: Interactivity (Optional Bonus)
#
# **Instructions:**
# - Use Plotly (or another interactive library) to create an interactive scatter plot of carat vs. price, colored by cut.
#
# **Reflection:**
# - What insights can you gain from interacting with the plot that you might miss in a static plot?

# %%
# Task 4: Your code here
import plotly.express as px
import seaborn as sns

diamonds = sns.load_dataset('diamonds')
sample = diamonds.sample(1000, random_state=2)

# Interactive scatter plot
fig = px.scatter(sample, x='carat', y='price', color='cut', hover_data=['depth', 'table'])
fig.show()

# %% [markdown]
# _Reflection for Task 4:_
# - saya menemukan bahwa berat pendorong utama harga berlian. Namun, ia juga menunjukkan bahwa Potongan (Cut) hanyalah salah satu dari faktor pendorong, kita harus mempertimbangkan semua faktor 4C (Carat, Cut, Color, Clarity) secara bersamaan.
