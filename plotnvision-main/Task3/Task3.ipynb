# %% [markdown]
# ## Task 3: Spatial/Geographical Mapping (Categorical Proxy)
#
# **Instructions:**
# - Create a heatmap showing the average price of diamonds by cut (rows) and color (columns).
#
# **Reflection:**
# - How does this “spatial” arrangement help you see patterns? What would be harder to see in a table?

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Task 3: Your code here
diamonds = sns.load_dataset('diamonds')
pivot = diamonds.pivot_table(index='cut', columns='color', values='price', aggfunc='mean')

# Heatmap of average price
plt.figure(figsize=(10, 6))
sns.heatmap(pivot, annot=True, fmt=".0f", cmap='YlGnBu')
plt.title('Average Diamond Price by Cut and Color')
plt.xlabel('Color')
plt.ylabel('Cut')
plt.show()
# Out:
# C:\Users\Katana\AppData\Local\Temp\ipykernel_21540\374899117.py:6: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot = diamonds.pivot_table(index='cut', columns='color', values='price', aggfunc='mean')

# %%
plt.figure(figsize=(10, 8)) # Mengatur ukuran gambar agar lebih jelas
sns.heatmap(
    pivot,
    annot=True,     # Menampilkan nilai numerik pada setiap sel
    fmt=".0f",      # Menggunakan format tanpa desimal
    cmap="YlGnBu",  # Mengatur palet warna (pilihan lain: "viridis", "plasma", "coolwarm")
    linewidths=.5,  # Menambahkan garis pemisah antar sel
    cbar_kws={'label': 'Average Price'} # Menambahkan label pada color bar
)

# Mengatur judul dan label
plt.title('Average Diamond Price by Cut and Color')
plt.xlabel('Color')
plt.ylabel('Cut')

# Menampilkan plot
plt.show()

# %% [markdown]
# _Reflection for Task 3:_
# - kita setelah melihat ini kita mengetahui bahwa ada beberapa fitur yang mempengaruhi harga rata rata emas di buktikan dengan warna dari kolomnya yang semakin gelap
